# %%
# Double check notebook set up

import sys
import sysconfig

# 1. This is where your code is looking for packages
print("Python is loading libraries from:", sysconfig.get_paths()["purelib"])

# 2. This is the exact interpreter executing this code
print("Active Python Interpreter:", sys.executable)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
response = model.invoke("What are the core components of LangChain?")
print(response.content)
